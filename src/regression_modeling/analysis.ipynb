# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import scipy.stats as stats
from sklearn.preprocessing import StandardScaler

# %%
# Load the data
df = pd.read_csv('behavior_result.csv')
df.head()
# Out:
#   filename  windowswitch_count_gpt  windowswitch_speed_gpt  totaltime_gpt  \
# 0  A2.json                       3              205.303000        615.909
# 1  A3.json                       4              201.143250        804.573
# 2  A4.json                      22               42.957364        945.062
# 3  A5.json                       2               25.405500         50.811
# 4  A6.json                       9               92.944333        836.499
#
#    click_count_gpt  total_mouse_movement_gpt  mousewheel_count_gpt  \
# 0               47              53245.778417                   145
# 1               22              26918.727912                   312
# 2               33              26747.643438                    69
# 3                6               5755.784963                    24
# 4               19              17445.667936                   524
#
#    total_mousewheel_distance_gpt  average_mousewheel_distance_gpt  \
# 0                   14499.999833                        99.999999
# 1                   26904.000000                        86.230769
# 2                    4390.535278                        63.630946
# 3                    2900.000000                       120.833333
# 4                   52500.000000                       100.190840
#
#    med_mousewheel_distance_gpt  ...  keypress_count_tasksheet  \
# 0                    99.999999  ...                        53
# 1                   102.000000  ...                       438
# 2                    24.888306  ...                        92
# 3                   100.000000  ...                         0
# 4                   100.000000  ...                         1
#
#    highlight_count_tasksheet  average_highlight_length_tasksheet  \
# 0                          2                           49.000000
# 1                          5                          195.800000
# 2                         12                          233.583333
# 3                          0                            0.000000
# 4                         14                          183.857143
#
#    med_highlight_length_tasksheet  idle_count_tasksheet  \
# 0                            49.0                     4
# 1                             2.0                    29
# 2                            24.0                    53
# 3                             0.0                     7
# 4                           142.0                    18
#
#    med_idle_duration_tasksheet  total_idle_duration_tasksheet  score_AI  \
# 0                       2005.0                           8022        32
# 1                       2002.0                          58043        61
# 2                       2002.0                         106222        51
# 3                       2013.0                          14819        65
# 4                       2011.5                          36165        30
#
#    score_alone  score_overreliance
# 0           61                 -29
# 1           42                  19
# 2           45                   6
# 3           55                  10
# 4           40                 -10
#
# [5 rows x 52 columns]

# %%
# EDA
df.describe()
# Out:
#        windowswitch_count_gpt  windowswitch_speed_gpt  totaltime_gpt  \
# count               22.000000               22.000000      22.000000
# mean                11.590909               73.909041     678.572727
# std                  8.404415               61.056609     302.834030
# min                  0.000000                0.000000      50.811000
# 25%                  4.250000               34.089208     509.468250
# 50%                  8.500000               46.336582     778.911000
# 75%                 19.000000               89.763967     911.041500
# max                 27.000000              205.303000    1203.343000
#
#        click_count_gpt  total_mouse_movement_gpt  mousewheel_count_gpt  \
# count        22.000000                 22.000000             22.000000
# mean         41.090909              39521.316930            541.636364
# std          35.730351              27751.214115            479.125050
# min           2.000000               5352.501218             24.000000
# 25%          10.000000              18797.375237            195.250000
# 50%          29.000000              31040.914363            458.000000
# 75%          65.500000              58061.730352            604.250000
# max         118.000000             105616.203855           1937.000000
#
#        total_mousewheel_distance_gpt  average_mousewheel_distance_gpt  \
# count                      22.000000                        22.000000
# mean                    25804.390102                        74.463182
# std                     21228.543310                        49.007149
# min                      2900.000000                         3.412552
# 25%                      7594.499658                        17.527517
# 50%                     16677.500000                        99.999999
# 75%                     43900.000000                       112.526126
# max                     63800.000000                       139.301310
#
#        med_mousewheel_distance_gpt  copy_count_gpt  ...  \
# count                    22.000000       22.000000  ...
# mean                     61.999227        4.318182  ...
# std                      47.830196        6.847915  ...
# min                       2.000000        0.000000  ...
# 25%                       8.000000        0.250000  ...
# 50%                      99.999999        1.500000  ...
# 75%                     100.000000        3.000000  ...
# max                     133.333325       28.000000  ...
#
#        keypress_count_tasksheet  highlight_count_tasksheet  \
# count                 22.000000                  22.000000
# mean                  92.772727                  18.272727
# std                  135.305626                  15.802899
# min                    0.000000                   0.000000
# 25%                   19.250000                   5.500000
# 50%                   68.500000                  15.000000
# 75%                   82.250000                  25.000000
# max                  548.000000                  55.000000
#
#        average_highlight_length_tasksheet  med_highlight_length_tasksheet  \
# count                           22.000000                       22.000000
# mean                           293.401453                      235.977273
# std                            383.310300                      449.812222
# min                              0.000000                        0.000000
# 25%                             70.526099                       23.125000
# 50%                            163.290210                       25.000000
# 75%                            245.645833                      125.875000
# max                           1339.000000                     1339.000000
#
#        idle_count_tasksheet  med_idle_duration_tasksheet  \
# count             22.000000                    22.000000
# mean              27.545455                  2016.681818
# std               16.343711                    34.249972
# min                4.000000                  2001.000000
# 25%               13.000000                  2002.000000
# 50%               30.000000                  2007.500000
# 75%               39.500000                  2011.000000
# max               53.000000                  2128.000000
#
#        total_idle_duration_tasksheet   score_AI  score_alone  \
# count                      22.000000  22.000000    22.000000
# mean                    57862.000000  48.636364    47.818182
# std                     34666.123524  14.039215    10.445488
# min                      8022.000000  22.000000    24.000000
# 25%                     26949.500000  37.250000    40.000000
# 50%                     63088.000000  50.500000    47.000000
# 75%                     83042.000000  62.500000    55.000000
# max                    118304.000000  69.000000    67.000000
#
#        score_overreliance
# count           22.000000
# mean             0.818182
# std             21.214632
# min            -40.000000
# 25%            -10.750000
# 50%              0.500000
# 75%             16.750000
# max             41.000000
#
# [8 rows x 51 columns]

# %%
# Determine what features might need to be transformed
# The features that are not normally distributed might need to be transformed
# We can use the Shapiro-Wilk test to determine if a feature is normally distributed
features = df.columns[1:-4]
transformed_features = []
for feature in features:
    stat, p = stats.shapiro(df[feature])
    print(f'{feature}: p-value = {p}')
    if p < 0.005:
        transformed_features.append(feature)

print(f'Transformed features: {transformed_features}')
# Out:
# windowswitch_count_gpt: p-value = 0.043588653206825256
# windowswitch_speed_gpt: p-value = 0.0008476412040181458
# totaltime_gpt: p-value = 0.2679891884326935
# click_count_gpt: p-value = 0.022310620173811913
# total_mouse_movement_gpt: p-value = 0.10608398914337158
# mousewheel_count_gpt: p-value = 0.002519912552088499
# total_mousewheel_distance_gpt: p-value = 0.008215234614908695
# average_mousewheel_distance_gpt: p-value = 0.004084073938429356
# med_mousewheel_distance_gpt: p-value = 0.00013355567352846265
# copy_count_gpt: p-value = 6.368940375978127e-06
# average_copy_length_gpt: p-value = 1.0316963198420126e-05
# med_copy_length_gpt: p-value = 1.5912102071524714e-06
# paste_count_gpt: p-value = 0.0012515896232798696
# average_paste_length_gpt: p-value = 0.005792492069303989
# med_paste_length_gpt: p-value = 0.0003027644124813378
# delete_count_gpt: p-value = 0.004361619707196951
# keypress_count_gpt: p-value = 0.007714137900620699
# highlight_count_gpt: p-value = 0.001662966562435031
# average_highlight_length_gpt: p-value = 0.0006044663023203611
# med_highlight_length_gpt: p-value = 3.288935658929404e-06
# idle_count_gpt: p-value = 0.185278058052063
# med_idle_duration_gpt: p-value = 2.4645976370862854e-09
# total_idle_duration_gpt: p-value = 0.22018513083457947
# prompts_count_gpt: p-value = 0.013598962686955929
# total_prompts_duration_gpt: p-value = 7.043339564916096e-07
# total_prompts_length_gpt: p-value = 0.0015438098926097155
# med_prompts_length_gpt: p-value = 5.8301480748923495e-05
# totaltime_tasksheet: p-value = 0.04769890010356903
# click_count_tasksheet: p-value = 0.05747095122933388
# total_mouse_movement_tasksheet: p-value = 0.034350696951150894
# mousewheel_count_tasksheet: p-value = 8.522970892954618e-05
# total_mousewheel_distance_tasksheet: p-value = 3.341204137541354e-05
# average_mousewheel_distance_tasksheet: p-value = 0.005394609645009041
# med_mousewheel_distance_tasksheet: p-value = 0.0002473795029800385
# copy_count_tasksheet: p-value = 0.018501129001379013
# average_copy_length_tasksheet: p-value = 0.0006938719307072461
# med_copy_length_tasksheet: p-value = 4.334783625381533e-06
# paste_count_tasksheet: p-value = 0.000617261219304055
# average_paste_length_tasksheet: p-value = 2.7690151682691067e-07
# med_paste_length_tasksheet: p-value = 1.4625830146997032e-07
# delete_count_tasksheet: p-value = 9.188173862639815e-05
# keypress_count_tasksheet: p-value = 8.167314717866248e-07
# highlight_count_tasksheet: p-value = 0.026901064440608025
# average_highlight_length_tasksheet: p-value = 1.8969521988765337e-05
# med_highlight_length_tasksheet: p-value = 3.400614900783694e-07
# idle_count_tasksheet: p-value = 0.0846167504787445
# med_idle_duration_tasksheet: p-value = 4.5598177678130014e-08
# Transformed features: ['windowswitch_speed_gpt', 'mousewheel_count_gpt', 'average_mousewheel_distance_gpt', 'med_mousewheel_distance_gpt', 'copy_count_gpt', 'average_copy_length_gpt', 'med_copy_length_gpt', 'paste_count_gpt', 'med_paste_length_gpt', 'delete_count_gpt', 'highlight_count_gpt', 'average_highlight_length_gpt', 'med_highlight_length_gpt', 'med_idle_duration_gpt', 'total_prompts_duration_gpt', 'total_prompts_length_gpt', 'med_prompts_length_gpt', 'mousewheel_count_tasksheet', 'total_mousewheel_distance_tasksheet', 'med_mousewheel_distance_tasksheet', 'average_copy_length_tasksheet', 'med_copy_length_tasksheet', 'paste_count_tasksheet', 'average_paste_length_tasksheet', 'med_paste_length_tasksheet', 'delete_count_tasksheet', 'keypress_count_tasksheet', 'average_highlight_length_tasksheet', 'med_highlight_length_tasksheet', 'med_idle_duration_tasksheet']

# %%
# transform the features
for feature in transformed_features:
    df[feature] = np.log(df[feature])


# visualize distribution of features after transformation
# for feature in features:
#     sns.histplot(df[feature])
#     plt.title(feature)
#     plt.show()
# Out:
# /Users/liubruce/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# Replace infinities with NaN
df = df.replace([np.inf, -np.inf], np.nan)

# Fill NaN values with the mean of the column
df = df.fillna(df.mean())
# Out:
# /var/folders/kz/2xjmg0wd0gb0tv1m30st5l0m0000gn/T/ipykernel_40502/2312700675.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df = df.fillna(df.mean())

# %%
# standardize the features
scaler = StandardScaler()
df[features] = scaler.fit_transform(df[features])

# %%
# check for multicollinearity
corr = df[features].corr()

# list of features that are highly correlated
highly_correlated_features = []
for i in range(len(corr.columns)):
    for j in range(i):
        if abs(corr.iloc[i, j]) > 0.8:
            highly_correlated_features.append((corr.columns[i], corr.columns[j]))

# randomly select one feature from each pair of highly correlated features
features_to_drop = []
for feature1, feature2 in highly_correlated_features:
    if feature1 not in features_to_drop:
        features_to_drop.append(feature2)

# drop the highly correlated features
df = df.drop(features_to_drop, axis=1)

print(f'Features to drop: {features_to_drop}')
# Out:
# Features to drop: ['click_count_gpt', 'average_mousewheel_distance_gpt', 'average_copy_length_gpt', 'paste_count_gpt', 'click_count_gpt', 'average_highlight_length_gpt', 'totaltime_gpt', 'totaltime_gpt', 'idle_count_gpt', 'totaltime_gpt', 'total_idle_duration_gpt', 'click_count_tasksheet', 'average_mousewheel_distance_gpt', 'med_mousewheel_distance_gpt', 'average_mousewheel_distance_gpt', 'med_mousewheel_distance_gpt', 'average_mousewheel_distance_tasksheet', 'average_copy_length_tasksheet', 'paste_count_tasksheet', 'paste_count_tasksheet', 'average_paste_length_tasksheet', 'click_count_tasksheet', 'total_mouse_movement_tasksheet', 'average_copy_length_tasksheet']

# %%
# Multiple linear regression
# remove score_AI score_alone score_overreliance and filename from the features
features = df.columns[1:-4]
X = df[features]
y = df['score_overreliance']

# add a constant to the features
X = sm.add_constant(X)

# fit the model
model = sm.OLS(y, X).fit()

# print the summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     score_overreliance   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.982
# Method:                 Least Squares   F-statistic:                     59.02
# Date:                Mon, 12 Aug 2024   Prob (F-statistic):              0.102
# Time:                        01:44:13   Log-Likelihood:                -20.089
# No. Observations:                  22   AIC:                             82.18
# Df Residuals:                       1   BIC:                             105.1
# Df Model:                          20
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                   0.8182      0.603      1.357      0.404      -6.844       8.480
# windowswitch_count_gpt                  3.2292      0.579      5.578      0.113      -4.127      10.585
# windowswitch_speed_gpt                 -4.0553      0.561     -7.234      0.087     -11.178       3.068
# total_mouse_movement_gpt              -18.4196      1.158    -15.910      0.040     -33.130      -3.710
# mousewheel_count_gpt                    9.0347      0.652     13.852      0.046       0.747      17.322
# total_mousewheel_distance_gpt          15.4465      0.841     18.372      0.035       4.764      26.129
# copy_count_gpt                          6.2001      0.912      6.801      0.093      -5.384      17.784
# med_copy_length_gpt                    10.5427      0.956     11.032      0.058      -1.600      22.686
# average_paste_length_gpt               -6.1166      0.929     -6.586      0.096     -17.917       5.684
# med_paste_length_gpt                    8.5689      0.963      8.895      0.071      -3.671      20.809
# delete_count_gpt                       -3.0155      1.117     -2.700      0.226     -17.205      11.174
# keypress_count_gpt                     -2.4198      0.870     -2.782      0.220     -13.471       8.631
# highlight_count_gpt                    -0.4031      0.613     -0.658      0.630      -8.188       7.382
# med_highlight_length_gpt               12.7254      0.909     14.006      0.045       1.181      24.270
# med_idle_duration_gpt                 -10.8979      0.822    -13.263      0.048     -21.338      -0.458
# prompts_count_gpt                      -8.5767      0.576    -14.888      0.043     -15.896      -1.257
# total_prompts_duration_gpt             -6.9750      1.266     -5.509      0.114     -23.063       9.113
# total_prompts_length_gpt                2.2740      0.535      4.252      0.147      -4.521       9.070
# med_prompts_length_gpt                  2.4864      0.723      3.438      0.180      -6.704      11.676
# totaltime_tasksheet                    -3.2678      0.822     -3.977      0.157     -13.708       7.172
# mousewheel_count_tasksheet             -4.6716      0.423    -11.045      0.057     -10.046       0.703
# total_mousewheel_distance_tasksheet     5.3423      0.631      8.466      0.075      -2.675      13.360
# med_mousewheel_distance_tasksheet       2.5610      0.514      4.982      0.126      -3.971       9.093
# copy_count_tasksheet                   -4.7790      0.797     -6.000      0.105     -14.900       5.342
# med_copy_length_tasksheet               2.1841      0.945      2.311      0.260      -9.826      14.194
# med_paste_length_tasksheet             -7.3726      0.583    -12.642      0.050     -14.782       0.037
# delete_count_tasksheet                  9.0143      0.601     15.005      0.042       1.381      16.648
# keypress_count_tasksheet               12.1095      0.882     13.727      0.046       0.901      23.318
# highlight_count_tasksheet              -7.1498      0.900     -7.948      0.080     -18.580       4.280
# average_highlight_length_tasksheet     -9.0688      0.988     -9.177      0.069     -21.626       3.488
# med_highlight_length_tasksheet        -12.1978      0.757    -16.104      0.039     -21.822      -2.573
# idle_count_tasksheet                    0.0780      0.557      0.140      0.911      -6.999       7.155
# med_idle_duration_tasksheet            17.5792      0.863     20.370      0.031       6.614      28.544
# ==============================================================================
# Omnibus:                       15.164   Durbin-Watson:                   3.000
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               58.667
# Skew:                          -0.000   Prob(JB):                     1.82e-13
# Kurtosis:                      11.000   Cond. No.                     1.24e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The smallest eigenvalue is 1.09e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# create a list of features with p-values less than 0.05
significant_features = model.pvalues[model.pvalues < 0.05].index.tolist()
print(f'Significant features: {significant_features}')
# Out:
# Significant features: ['total_mouse_movement_gpt', 'mousewheel_count_gpt', 'total_mousewheel_distance_gpt', 'med_highlight_length_gpt', 'med_idle_duration_gpt', 'prompts_count_gpt', 'delete_count_tasksheet', 'keypress_count_tasksheet', 'med_highlight_length_tasksheet', 'med_idle_duration_tasksheet']
